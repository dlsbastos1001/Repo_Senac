# %%
import pandas as pd

df= pd.read_csv('CARAMELO.csv', sep=';')
df
# Out:
#         ID Venda                             Loja  ID Loja Estado Loja  \
# 0              1                             Melo       49          BA
# 1             10           Mendonça Machado Ltda.        7          SP
# 2           1000                Cunha Mendes S.A.       97          BA
# 3         100001                            Nunes       77          MG
# 4         100007                Cunha Mendes S.A.       97          BA
# ...          ...                              ...      ...         ...
# 149995     99992                          Barbosa       96          RS
# 149996     99994  Aparecida da Conceição e Filhos       15          RJ
# 149997     99997                          Moreira       53          RJ
# 149998     99998                          Andrade       94          SP
# 149999     99999                         Teixeira       49          RS
#
#                   Cidade Loja            Nome Cliente  ID Cliente       Sexo  \
# ...

# %%
df['Valor de Venda'] = df['Valor de Venda'].str.replace(',', '.').astype(float)
#done

# %%
df_coca = df.loc[df['Marca'] == 'Coca-Cola']
df_coca

# %%
df_vale = df.loc[df['Marca'] == 'Del Valle']
df_vale

# %%
df_vale = df.groupby('Cidade Loja')['Valor de Venda'].mean().reset_index()
df_vale
# Out:
#               Cidade Loja  Valor de Venda
# 0                Camaçari      926.894189
# 1                Campinas      904.022311
# 2   Campos dos Goytacazes     1093.946287
# 3           Caxias do Sul     1133.995560
# 4                Contagem     1095.791096
# 5           Novo Hamburgo      911.327540
# 6                 Pelotas      869.794751
# 7            Porto Alegre     1046.748214
# 8          Ribeirão Preto     1037.533104
# 9          Rio de Janeiro     1151.400264
# 10               Salvador      987.868738
# 11                 Santos      923.435035
# 12               Sorocaba     1030.528988
# 13             Uberlândia     1294.083196
